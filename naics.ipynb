# %% [markdown]
# # Testing NAICIS Codes

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('bloomington_transient_visits_02_2020.csv')
data[data.naics_code == 722511.0]
# Out:
#                        safegraph_place_id  \
# 0     sg:39545556567845c4bf82ecb8968876fb
# 5     sg:d1298bda8d12413992c6cd22cf1feae5
# 19    sg:455be4495c0645d08f40ad5d619380ba
# 20    sg:ea461a6dd7364df48ece56cfc54493a5
# 21    sg:19632d108f6a473486b1be4919172180
# ...                                   ...
# 3254  sg:287d997cb1a04505aafe54bb088c7a94
# 3255  sg:7ca0da5a313640bea3b55d599df34323
# 3256  sg:7ab39c18c5c6448280ca974a4012e956
# 3257  sg:750726af9d654b7594da285503952696
# 3263  sg:729747a337a3453eb692786d6a6324e0
#
#                             location_name               street_address  \
# 0     Open City At the National Cathedral           2331 Calvert St NW
# 5                      Fire and Brimstone                3000 E Ray Rd
# 19                                RusTeak            2625 Edgewater Dr
# 20                    Del Frisco's Grille  501 E Las Olas Blvd Ste 150
# 21                       The Friar's Nook           1180 Seven Seas Dr
# ...
