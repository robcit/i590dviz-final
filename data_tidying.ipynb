# %% [markdown]
# Now I have to find out where all of these transient Bloomington citizens visit.
#
# Test case: January 2020 (which includes part of winter break)

# %%
import pandas as pd

# %%
# Pull in monthly pattern data
jan1 = pd.read_csv('../monthly-data/2020/01/patterns-part1.csv')
jan1.head()
# Out:
#                     safegraph_place_id                          location_name  \
# 0  sg:0002d23e6d2b49e28f46ce1dc372bd91                              Shell Oil
# 1  sg:0019b82576a444f0aadd7ca4c2b8aaf5  Larry Mann DO Bronson Family Medicine
# 2  sg:002d1201d575489b9932bfe440755910           Halifax Plantation Golf Club
# 3  sg:0062e5aba6f7452fa0216176269bea39                               Days Inn
# 4  sg:009899f0f8254dadbcd4c9a6e00523b0     Itawamba Career & Technical Center
#
#           street_address           city region  postal_code  \
# 0          2 Del Fino Pl  Carmel Valley     CA        93924
# 1        2900 Watkins Rd   Battle Creek     MI        49015
# 2      3400 Clubhouse Dr   Ormond Beach     FL        32174
# 3  2550 Georgetown Rd NW      Cleveland     TN        37311
# 4         200 Vo Tech Rd         Fulton     MS        38843
#
#                          safegraph_brand_ids     brands  \
# 0  SG_BRAND_2591c98b70119fe624898b1e424b5e91  Shell Oil
# ...

# %%
jan1.count
# Out:
# <bound method DataFrame.count of                           safegraph_place_id  \
# 0        sg:0002d23e6d2b49e28f46ce1dc372bd91
# 1        sg:0019b82576a444f0aadd7ca4c2b8aaf5
# 2        sg:002d1201d575489b9932bfe440755910
# 3        sg:0062e5aba6f7452fa0216176269bea39
# 4        sg:009899f0f8254dadbcd4c9a6e00523b0
# ...                                      ...
# 1078201  sg:ff71c562e7874f0d9ed73236017a17e6
# 1078202  sg:ffa4e3b992a643849c4b0d316650e249
# 1078203  sg:ffdc44f0bef8430f97ccf08b4325e7e0
# 1078204  sg:ffddda1dc3b64c77b6f5d33136dccae7
# 1078205  sg:ffe9904e922849c3a599e1c93ddc9198
#
#                                  location_name  \
# 0                                    Shell Oil
# 1        Larry Mann DO Bronson Family Medicine
# 2                 Halifax Plantation Golf Club
# 3                                     Days Inn
# 4           Itawamba Career & Technical Center
# ...                                        ...
# 1078201                              Starbucks
# ...

# %%
# OK let's try to melt this.  Aieee.
# Let's get a small subset
jan1_temp = jan1[:100]
jan1_temp = jan1_temp[['safegraph_place_id', 'location_name', 'visitor_home_cbgs']]
jan1_temp
# Out:
#                      safegraph_place_id  \
# 0   sg:0002d23e6d2b49e28f46ce1dc372bd91
# 1   sg:0019b82576a444f0aadd7ca4c2b8aaf5
# 2   sg:002d1201d575489b9932bfe440755910
# 3   sg:0062e5aba6f7452fa0216176269bea39
# 4   sg:009899f0f8254dadbcd4c9a6e00523b0
# ..                                  ...
# 95  sg:070e5ca20ea545c6962cc510c64d183e
# 96  sg:07140c2e5df84af2a9dffe69b6ca7685
# 97  sg:074452074e9a4a8687c94d52b6a314c6
# 98  sg:0759ce9a1319403cb11060568340c66d
# 99  sg:0792d45e650849d982665b6ab5bbb663
#
#                             location_name  \
# 0                               Shell Oil
# 1   Larry Mann DO Bronson Family Medicine
# 2            Halifax Plantation Golf Club
# 3                                Days Inn
# 4      Itawamba Career & Technical Center
# ..                                    ...
# 95     Royal Coaches Auto Body and Towing
# 96                         Chizel Fitness
# 97                          Le Reve Nails
# 98                     Sun Lovers Tanning
# ...

# %%
data = [{'id': 1, 'name': {'first': 'Coleen', 'last': 'Volk'}},
        {'name': {'given': 'Mose', 'family': 'Regner'}},
        {'id': 2, 'name': 'Faye Raker'}]
pd.json_normalize(jan1_temp.visitor_home_cbgs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-fbf47fb21c57> in <module>
#       2         {'name': {'given': 'Mose', 'family': 'Regner'}},
#       3         {'id': 2, 'name': 'Faye Raker'}]
# ----> 4 pd.json_normalize(jan1_temp.visitor_home_cbgs)
#
# ~/anaconda3/envs/dviz/lib/python3.8/site-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     272
#     273     if record_path is None:
# --> 274         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     275             # naive normalization, this is idempotent for flat records
#     276             # and potentially will inflate the data considerably for
#
# ~/anaconda3/envs/dviz/lib/python3.8/site-packages/pandas/io/json/_normalize.py in <genexpr>(.0)
#     272
#     273     if record_path is None:
# ...
