# %%
#import pandas
import pandas as pd
import numpy as np

# %%
#import sample data
data = pd.read_csv('../monthly-data/2020/01/patterns-SAMPLE.csv')
data['safegraph_place_id']
data.dtypes
# Out:
# Unnamed: 0                     int64
# safegraph_place_id            object
# location_name                 object
# street_address                object
# city                          object
# region                        object
# postal_code                    int64
# safegraph_brand_ids           object
# brands                        object
# date_range_start              object
# date_range_end                object
# raw_visit_counts               int64
# raw_visitor_counts             int64
# visits_by_day                 object
# poi_cbg                      float64
# visitor_home_cbgs             object
# visitor_daytime_cbgs          object
# visitor_work_cbgs             object
# visitor_country_of_origin     object
# distance_from_home           float64
# median_dwell                 float64
# bucketed_dwell_times          object
# related_same_day_brand        object
# related_same_month_brand      object
# popularity_by_hour            object
# popularity_by_day             object
# device_type                   object
# dtype: object

# %%
df = data

from ast import literal_eval
df.visitor_home_cbgs = df.visitor_home_cbgs.apply(literal_eval)

# %%
pd.json_normalize(df.visitor_home_cbgs)
# Out:
#     060530110002  060530118011  060530110001  060530110003  060133720005  \
# 0            8.0           8.0           7.0           5.0           4.0
# 1            NaN           NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN           NaN
# 3            NaN           NaN           NaN           NaN           NaN
# 4            NaN           NaN           NaN           NaN           NaN
# ..           ...           ...           ...           ...           ...
# 95           NaN           NaN           NaN           NaN           NaN
# 96           NaN           NaN           NaN           NaN           NaN
# 97           NaN           NaN           NaN           NaN           NaN
# 98           NaN           NaN           NaN           NaN           NaN
# 99           NaN           NaN           NaN           NaN           NaN
#
#     060530110004  060530107012  060530110005  060530111011  060730178132  ...  \
# 0            4.0           4.0           4.0           4.0           4.0  ...
# 1            NaN           NaN           NaN           NaN           NaN  ...
# 2            NaN           NaN           NaN           NaN           NaN  ...
# 3            NaN           NaN           NaN           NaN           NaN  ...
# 4            NaN           NaN           NaN           NaN           NaN  ...
# ..           ...           ...           ...           ...           ...  ...
# 95           NaN           NaN           NaN           NaN           NaN  ...
# 96           NaN           NaN           NaN           NaN           NaN  ...
# 97           NaN           NaN           NaN           NaN           NaN  ...
# 98           NaN           NaN           NaN           NaN           NaN  ...
# 99           NaN           NaN           NaN           NaN           NaN  ...
#
#     530530723101  060374048012  060374069013  340297351033  340270440001  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1            NaN           NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN           NaN
# 3            NaN           NaN           NaN           NaN           NaN
# 4            NaN           NaN           NaN           NaN           NaN
# ..           ...           ...           ...           ...           ...
# 95           NaN           4.0           4.0           NaN           NaN
# 96           NaN           NaN           NaN           4.0           4.0
# 97           NaN           NaN           NaN           NaN           NaN
# 98           NaN           NaN           NaN           NaN           NaN
# 99           NaN           NaN           NaN           NaN           NaN
#
#     200910529063  261210028001  261210004023  261210028002  261210031002
# 0            NaN           NaN           NaN           NaN           NaN
# 1            NaN           NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN           NaN
# 3            NaN           NaN           NaN           NaN           NaN
# 4            NaN           NaN           NaN           NaN           NaN
# ..           ...           ...           ...           ...           ...
# 95           NaN           NaN           NaN           NaN           NaN
# 96           NaN           NaN           NaN           NaN           NaN
# 97           4.0           NaN           NaN           NaN           NaN
# 98           NaN           4.0           4.0           4.0           4.0
# 99           NaN           NaN           NaN           NaN           NaN
#
# [100 rows x 31141 columns]

# %%
df2 = df.visitor_home_cbgs.apply(pd.Series)
combined_df = pd.concat([df, df2], axis=1)
combined_df = combined_df.drop(['visitor_home_cbgs'], axis=1)
combined_df
# Out:
#     Unnamed: 0                   safegraph_place_id  \
# 0            0  sg:0002d23e6d2b49e28f46ce1dc372bd91
# 1            1  sg:0019b82576a444f0aadd7ca4c2b8aaf5
# 2            2  sg:002d1201d575489b9932bfe440755910
# 3            3  sg:0062e5aba6f7452fa0216176269bea39
# 4            4  sg:009899f0f8254dadbcd4c9a6e00523b0
# ..         ...                                  ...
# 95          95  sg:070e5ca20ea545c6962cc510c64d183e
# 96          96  sg:07140c2e5df84af2a9dffe69b6ca7685
# 97          97  sg:074452074e9a4a8687c94d52b6a314c6
# 98          98  sg:0759ce9a1319403cb11060568340c66d
# 99          99  sg:0792d45e650849d982665b6ab5bbb663
#
#                             location_name              street_address  \
# 0                               Shell Oil               2 Del Fino Pl
# 1   Larry Mann DO Bronson Family Medicine             2900 Watkins Rd
# 2            Halifax Plantation Golf Club           3400 Clubhouse Dr
# 3                                Days Inn       2550 Georgetown Rd NW
# 4      Itawamba Career & Technical Center              200 Vo Tech Rd
# ..                                    ...                         ...
# 95     Royal Coaches Auto Body and Towing           14827 Ramona Blvd
# 96                         Chizel Fitness        2701 Long Beach Blvd
# 97                          Le Reve Nails  13511 S Mur Len Rd Ste 130
# 98                     Sun Lovers Tanning               215 N 3rd Ave
# 99                       Independent Bank               3251 Henry St
#
#              city region  postal_code  \
# 0   Carmel Valley     CA        93924
# 1    Battle Creek     MI        49015
# 2    Ormond Beach     FL        32174
# 3       Cleveland     TN        37311
# 4          Fulton     MS        38843
# ..            ...    ...          ...
# 95   Baldwin Park     CA        91706
# 96    Ship Bottom     NJ         8008
# 97         Olathe     KS        66062
# 98      Fruitport     MI        49415
# 99       Muskegon     MI        49441
#
#                           safegraph_brand_ids     brands  \
# 0   SG_BRAND_2591c98b70119fe624898b1e424b5e91  Shell Oil
# 1                                         NaN        NaN
# 2                                         NaN        NaN
# 3   SG_BRAND_f0f5c15118ea292fadac17e2fc7d4ead   Days Inn
# 4                                         NaN        NaN
# ..                                        ...        ...
# 95                                        NaN        NaN
# 96                                        NaN        NaN
# 97                                        NaN        NaN
# 98                                        NaN        NaN
# 99                                        NaN        NaN
#
#              date_range_start  ... 530530723101  060374048012  060374069013  \
# 0   2020-01-01T00:00:00-08:00  ...          NaN           NaN           NaN
# 1   2020-01-01T00:00:00-05:00  ...          NaN           NaN           NaN
# 2   2020-01-01T00:00:00-05:00  ...          NaN           NaN           NaN
# 3   2020-01-01T00:00:00-05:00  ...          NaN           NaN           NaN
# 4   2020-01-01T00:00:00-06:00  ...          NaN           NaN           NaN
# ..                        ...  ...          ...           ...           ...
# 95  2020-01-01T00:00:00-08:00  ...          NaN           4.0           4.0
# 96  2020-01-01T00:00:00-05:00  ...          NaN           NaN           NaN
# 97  2020-01-01T00:00:00-06:00  ...          NaN           NaN           NaN
# 98  2020-01-01T00:00:00-05:00  ...          NaN           NaN           NaN
# 99  2020-01-01T00:00:00-05:00  ...          NaN           NaN           NaN
#
#    340297351033  340270440001 200910529063 261210028001 261210004023  \
# 0           NaN           NaN          NaN          NaN          NaN
# 1           NaN           NaN          NaN          NaN          NaN
# 2           NaN           NaN          NaN          NaN          NaN
# 3           NaN           NaN          NaN          NaN          NaN
# 4           NaN           NaN          NaN          NaN          NaN
# ..          ...           ...          ...          ...          ...
# 95          NaN           NaN          NaN          NaN          NaN
# 96          4.0           4.0          NaN          NaN          NaN
# 97          NaN           NaN          4.0          NaN          NaN
# 98          NaN           NaN          NaN          4.0          4.0
# 99          NaN           NaN          NaN          NaN          NaN
#
#     261210028002  261210031002
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# ..           ...           ...
# 95           NaN           NaN
# 96           NaN           NaN
# 97           NaN           NaN
# 98           4.0           4.0
# 99           NaN           NaN
#
# [100 rows x 31167 columns]

# %%
# Get an array of the Transient CBGs for Bloomington and convert them each to strings
transient_df = pd.read_csv('bton_transient_cbgs.csv')
transient_df.census_block_group = transient_df.census_block_group.astype(str)
transient_df.dtypes
# Out:
# Unnamed: 0              int64
# census_block_group     object
# devices07222019         int64
# devices02032020         int64
# pop_change              int64
# pop_pct_change        float64
# dtype: object

# %%
transient = transient_df.census_block_group.to_numpy()
transient
# Out:
# array(['181050002011', '181050002012', '181050002013', '181050002021',
#        '181050002022', '181050003014', '181050003021', '181050007003',
#        '181050012002', '181050012005', '181050013014', '181050014012',
#        '181050016001', '181050016002', '181050016003'], dtype=object)

# %%
# Get array of dataframe columns
list(combined_df.columns[1:26])
visitor_cbgs = combined_df.columns[27:].to_numpy()
visitor_cbgs

# %%
# Find out which CBGs appear in BOTH the bton_transient list as well as in the visit data
# This should give us a list of only locations that were visited by residents of the Bton transient CBGs
bton_transient_visits = np.intersect1d(transient, visitor_cbgs)
bton_transient_visits
# Out:
# array(['181050002011', '181050002013', '181050002021', '181050003014',
#        '181050007003', '181050016001', '181050016003'], dtype=object)

# %%
melted_df = pd.melt(combined_df, id_vars=['safegraph_place_id'], value_vars=bton_transient_visits, var_name='home_cbg', value_name='visits')
melted_df = melted_df.dropna()
melted_df.visits = melted_df.visits.astype(int)
melted_df
# Out:
#                       safegraph_place_id      home_cbg  visits
# 74   sg:056ae699cec14a6796ae68bba2078a67  181050002011       4
# 174  sg:056ae699cec14a6796ae68bba2078a67  181050002013       4
# 274  sg:056ae699cec14a6796ae68bba2078a67  181050002021       8
# 374  sg:056ae699cec14a6796ae68bba2078a67  181050003014       4
# 474  sg:056ae699cec14a6796ae68bba2078a67  181050007003       4
# 574  sg:056ae699cec14a6796ae68bba2078a67  181050016001       4
# 613  sg:014dc5287531458dbded5b63a9cea939  181050016003       4

# %%
# Join this back with the original data so that each location has a separate row for each home_cbg in the Bton transient list

merged_df = pd.merge(data, melted_df, on='safegraph_place_id')
merged_df
# Out:
#    Unnamed: 0                   safegraph_place_id             location_name  \
# 0          13  sg:014dc5287531458dbded5b63a9cea939        The Art of Shaving
# 1          74  sg:056ae699cec14a6796ae68bba2078a67  Walt Disney World Resort
# 2          74  sg:056ae699cec14a6796ae68bba2078a67  Walt Disney World Resort
# 3          74  sg:056ae699cec14a6796ae68bba2078a67  Walt Disney World Resort
# 4          74  sg:056ae699cec14a6796ae68bba2078a67  Walt Disney World Resort
# 5          74  sg:056ae699cec14a6796ae68bba2078a67  Walt Disney World Resort
# 6          74  sg:056ae699cec14a6796ae68bba2078a67  Walt Disney World Resort
#
#                   street_address     city region  postal_code  \
# 0  2801 W Big Beaver Rd Ste K240     Troy     MI        48084
# 1       Walt Disney World Resort  Orlando     FL        32830
# 2       Walt Disney World Resort  Orlando     FL        32830
# 3       Walt Disney World Resort  Orlando     FL        32830
# 4       Walt Disney World Resort  Orlando     FL        32830
# 5       Walt Disney World Resort  Orlando     FL        32830
# 6       Walt Disney World Resort  Orlando     FL        32830
#
#          safegraph_brand_ids                         brands  \
# 0  SG_BRAND_2b2de6e5e806bd0b             The Art of Shaving
# 1  SG_BRAND_434e9aa0a55d5fb7  Walt Disney Parks and Resorts
# 2  SG_BRAND_434e9aa0a55d5fb7  Walt Disney Parks and Resorts
# 3  SG_BRAND_434e9aa0a55d5fb7  Walt Disney Parks and Resorts
# 4  SG_BRAND_434e9aa0a55d5fb7  Walt Disney Parks and Resorts
# 5  SG_BRAND_434e9aa0a55d5fb7  Walt Disney Parks and Resorts
# 6  SG_BRAND_434e9aa0a55d5fb7  Walt Disney Parks and Resorts
#
#             date_range_start  ... distance_from_home  median_dwell  \
# 0  2020-01-01T00:00:00-05:00  ...            20866.0          21.0
# 1  2020-01-01T00:00:00-05:00  ...           302269.0         187.0
# 2  2020-01-01T00:00:00-05:00  ...           302269.0         187.0
# 3  2020-01-01T00:00:00-05:00  ...           302269.0         187.0
# 4  2020-01-01T00:00:00-05:00  ...           302269.0         187.0
# 5  2020-01-01T00:00:00-05:00  ...           302269.0         187.0
# 6  2020-01-01T00:00:00-05:00  ...           302269.0         187.0
#
#                                 bucketed_dwell_times  \
# 0  {"<5":58,"5-20":1565,"21-60":1440,"61-240":384...
# 1  {"<5":8262,"5-20":172924,"21-60":140450,"61-24...
# 2  {"<5":8262,"5-20":172924,"21-60":140450,"61-24...
# 3  {"<5":8262,"5-20":172924,"21-60":140450,"61-24...
# 4  {"<5":8262,"5-20":172924,"21-60":140450,"61-24...
# 5  {"<5":8262,"5-20":172924,"21-60":140450,"61-24...
# 6  {"<5":8262,"5-20":172924,"21-60":140450,"61-24...
#
#                               related_same_day_brand  \
# 0  {"Tesla Motors":43,"Macy's":9,"Bath & Body Wor...
# 1                                                 {}
# 2                                                 {}
# 3                                                 {}
# 4                                                 {}
# 5                                                 {}
# 6                                                 {}
#
#                             related_same_month_brand  \
# 0  {"Tesla Motors":65,"Starbucks":36,"Kroger":33,...
# 1  {"Publix Super Markets":21,"Walmart":20,"McDon...
# 2  {"Publix Super Markets":21,"Walmart":20,"McDon...
# 3  {"Publix Super Markets":21,"Walmart":20,"McDon...
# 4  {"Publix Super Markets":21,"Walmart":20,"McDon...
# 5  {"Publix Super Markets":21,"Walmart":20,"McDon...
# 6  {"Publix Super Markets":21,"Walmart":20,"McDon...
#
#                                   popularity_by_hour  \
# 0  [7,5,3,2,1,0,8,17,41,95,193,289,451,625,739,76...
# 1  [239196,228945,226172,227811,232970,245325,272...
# 2  [239196,228945,226172,227811,232970,245325,272...
# 3  [239196,228945,226172,227811,232970,245325,272...
# 4  [239196,228945,226172,227811,232970,245325,272...
# 5  [239196,228945,226172,227811,232970,245325,272...
# 6  [239196,228945,226172,227811,232970,245325,272...
#
#                                    popularity_by_day  \
# 0  {"Monday":379,"Tuesday":215,"Wednesday":435,"T...
# 1  {"Monday":135376,"Tuesday":114608,"Wednesday":...
# 2  {"Monday":135376,"Tuesday":114608,"Wednesday":...
# 3  {"Monday":135376,"Tuesday":114608,"Wednesday":...
# 4  {"Monday":135376,"Tuesday":114608,"Wednesday":...
# 5  {"Monday":135376,"Tuesday":114608,"Wednesday":...
# 6  {"Monday":135376,"Tuesday":114608,"Wednesday":...
#
#                        device_type      home_cbg  visits
# 0       {"android":600,"ios":2355}  181050016003       4
# 1  {"android":117264,"ios":154739}  181050002011       4
# 2  {"android":117264,"ios":154739}  181050002013       4
# 3  {"android":117264,"ios":154739}  181050002021       8
# 4  {"android":117264,"ios":154739}  181050003014       4
# 5  {"android":117264,"ios":154739}  181050007003       4
# 6  {"android":117264,"ios":154739}  181050016001       4
#
# [7 rows x 29 columns]
